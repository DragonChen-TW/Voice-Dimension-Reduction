# %%
import pandas as pd
import torch

# %%
df = pd.read_csv('voice.csv')
df
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
#              kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0      274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1      634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2     1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3        4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4        4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
# ...           ...       ...       ...  ...       ...       ...       ...
# 3163     6.630383  0.962934  0.763182  ...  0.131884  0.182790  0.083770
# 3164     2.503954  0.960716  0.709570  ...  0.116221  0.188980  0.034409
# 3165     6.604509  0.946854  0.654196  ...  0.142056  0.209918  0.039506
# 3166     5.388298  0.950436  0.675470  ...  0.143659  0.172375  0.034483
# 3167     5.769115  0.938829  0.601529  ...  0.165509  0.185607  0.062257
#
#         maxfun   meandom    mindom    maxdom   dfrange   modindx   label
# 0     0.275862  0.007812  0.007812  0.007812  0.000000  0.000000    male
# 1     0.250000  0.009014  0.007812  0.054688  0.046875  0.052632    male
# 2     0.271186  0.007990  0.007812  0.015625  0.007812  0.046512    male
# 3     0.250000  0.201497  0.007812  0.562500  0.554688  0.247119    male
# 4     0.266667  0.712812  0.007812  5.484375  5.476562  0.208274    male
# ...        ...       ...       ...       ...       ...       ...     ...
# 3163  0.262295  0.832899  0.007812  4.210938  4.203125  0.161929  female
# 3164  0.275862  0.909856  0.039062  3.679688  3.640625  0.277897  female
# 3165  0.275862  0.494271  0.007812  2.937500  2.929688  0.194759  female
# 3166  0.250000  0.791360  0.007812  3.593750  3.585938  0.311002  female
# 3167  0.271186  0.227022  0.007812  0.554688  0.546875  0.350000  female
#
# [3168 rows x 21 columns]

# %%
x = df.values[:, :-1]
x = torch.tensor(x.astype('float32'))
y = df.values[:, -1]
print('y', y)
y[y == 'male'] = 0
y[y == 'female'] = 1
print('y', y)
y = torch.tensor(y.astype('float32'))
# Out:
# y ['male' 'male' 'male' ... 'female' 'female' 'female']
# y [0 0 0 ... 1 1 1]

# %%
from torch.utils.data import random_split, DataLoader, Dataset

# %%
class TensorDataset(Dataset):
    def __init__(self, *tensors, mu, std):
        assert all(tensors[0].size(0) == tensor.size(0) for tensor in tensors), "Size mismatch between tensors"
        self.tensors = tensors
        self.mu = mu
        self.std = std

    def __getitem__(self, index):
        x = self.tensors[0][index]
        x = (x - self.mu) / self.std
        y = self.tensors[1][index]
        return (x, y)

    def __len__(self):
        return self.tensors[0].size(0)

# %%
train_size = round(len(x) * 0.7)
test_size = len(x) - train_size
train_idx, test_idx = random_split(range(len(x)), [train_size, test_size])
mu = x[train_idx].mean(dim=0)
std = x[train_idx].std(dim=0)

# %%
dataset_train = TensorDataset(x[train_idx], y[train_idx], mu=mu, std=std)
dataset_test = TensorDataset(x[test_idx], y[test_idx], mu=mu, std=std)

# %%
print('train', len(dataset_train))
print('test', len(dataset_test))
# Out:
# train 2218
# test 950

# %%
batch_size = 64
train_data = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
test_data = DataLoader(dataset_test, batch_size=batch_size, shuffle=False)

# %%
from torch import nn

class VoiceEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(20, 12),
            nn.ReLU(True),
            nn.BatchNorm1d(12),
            nn.Linear(12, 7),
            nn.ReLU(True),
            nn.BatchNorm1d(7),
            nn.Linear(7, 2),
        )
    
    def forward(self, x):
        return self.encoder(x)

class VoiceDownStream(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = VoiceEncoder()
        self.down = nn.Sequential(
            nn.Linear(2, 3),
            nn.ReLU(True),
            nn.BatchNorm1d(3),
            nn.Linear(3, 1),
        )

    def forward(self, x):
        encode = self.encoder(x)
        out = self.down(encode)
        return torch.sigmoid(out)

# %%
device = torch.device('cuda:2')
model = VoiceDownStream().to(device)
criterion = nn.BCELoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-3)

# %%
# test model
test_x = torch.rand(16, 20).to(device)
model(test_x).shape
# Out:
# torch.Size([16, 1])

# %%
# ckpt = torch.load('ckpts/ae20,12,7,5_lr1e-3_l0.0925.pt')
# ckpt = torch.load('ckpts/ae20,12,7,5_lr1e-2_l0.0977.pt')
ckpt = torch.load('ckpts/ae_dim2.pt')
model.load_state_dict(ckpt, False)

for p in model.encoder.parameters():
    p.requires_grad = False

# %%
from tqdm import tqdm
def train(model, data, epoch, criterion, optimizer, device, is_tqdm=False):
    model.train()
    loss_list = []
    acc_count = 0

    loader = enumerate(data)
    if is_tqdm:
        loader = tqdm(loader, total=len(data))
    for i, (batch, label) in loader:
        batch = batch.to(device)
        label = label.to(device).float()

        optimizer.zero_grad()
        score = model(batch).squeeze() # predict the label
        loss = criterion(score, label) # calculate error
        loss_list.append(loss.item())
        
        pred = score.round()
        acc_count += pred.eq(label).sum().item()
        
        loss.backward()  # back-propagation
        optimizer.step() # gradient descent

    acc = acc_count / (len(data) * data.batch_size) * 100
    return sum(loss_list) / len(loss_list), acc

def test(model, data, criterion, device, is_tqdm=False):
    model.eval()
    loss_list = []

    acc_count = 0
    loader = enumerate(data)
    if is_tqdm:
        loader = tqdm(loader, total=len(data))
    for i, (batch, label) in loader:
        batch = batch.to(device)
        label = label.to(device).float()

        score = model(batch).squeeze()
        loss = criterion(score, label)
        loss_list.append(loss.item())

        pred = score.round()
        acc_count += pred.eq(label).sum().item()

    acc = acc_count / (len(data) * data.batch_size) * 100
    return sum(loss_list) / len(loss_list), acc

# %%
import matplotlib.pyplot as plt

class Meter:
    def __init__(self):
        self.train_loss_list = []
        self.train_acc_list = []
        self.val_loss_list = []
        self.val_acc_list = []
    
    def update(self, train_loss, train_acc, val_loss, val_acc):
        self.train_loss_list.append(train_loss)
        self.train_acc_list.append(train_acc)
        self.val_loss_list.append(val_loss)
        self.val_acc_list.append(val_acc)
    
    def plot(self):
        x = range(len(self.train_loss_list))
        plt.figure(figsize=(12, 4))
        plt.plot(x, self.train_loss_list)
        plt.plot(x, self.val_loss_list, color='r')
        plt.legend(['train_loss', 'val_loss'])
        plt.show()
        plt.figure(figsize=(12, 4))
        plt.plot(x, self.train_acc_list)
        plt.plot(x, self.val_acc_list, color='r')
        plt.legend(['train_acc', 'val_acc'])
        plt.show()

# %%
from torch.optim.lr_scheduler import StepLR

max_epoch = 90
step_size = 30
log_interval = 5

scheduler = StepLR(optimizer, step_size=step_size, gamma=0.2)

meter = Meter()

for epoch in range(1, max_epoch + 1):
    if epoch % log_interval == 0:
        tqdm.write('==========Train Epoch {}=========='.format(epoch))
    train_loss, train_acc = train(model, train_data, epoch, criterion, optimizer, device)
    test_loss, test_acc = test(model, test_data, criterion, device)
    scheduler.step()
    
    meter.update(train_loss, train_acc, test_loss, test_acc)
    
    if epoch % log_interval == 0:
        print('Train loss: {:.04f} acc: {:.02f} - Test loss: {:.04f} acc: {:.02f}'.format(
            train_loss, train_acc, test_loss, test_acc
        ))
# Out:
# ==========Train Epoch 5==========
# Train loss: 0.5454 acc: 76.43 - Test loss: 0.5328 acc: 76.04
# ==========Train Epoch 10==========
# Train loss: 0.4682 acc: 82.90 - Test loss: 0.4614 acc: 83.85
# ==========Train Epoch 15==========
# Train loss: 0.3956 acc: 83.62 - Test loss: 0.3900 acc: 84.27
# ==========Train Epoch 20==========
# Train loss: 0.3710 acc: 84.06 - Test loss: 0.3644 acc: 84.27
# ==========Train Epoch 25==========
# Train loss: 0.3596 acc: 84.82 - Test loss: 0.3578 acc: 84.79
# ==========Train Epoch 30==========
# Train loss: 0.3568 acc: 84.60 - Test loss: 0.3510 acc: 85.52
# ==========Train Epoch 35==========
# Train loss: 0.3542 acc: 85.27 - Test loss: 0.3512 acc: 85.10
# ==========Train Epoch 40==========
# Train loss: 0.3600 acc: 85.27 - Test loss: 0.3517 acc: 85.31
# ==========Train Epoch 45==========
# Train loss: 0.3531 acc: 84.82 - Test loss: 0.3508 acc: 84.79
# ==========Train Epoch 50==========
# Train loss: 0.3543 acc: 84.82 - Test loss: 0.3525 acc: 85.00
# ==========Train Epoch 55==========
# Train loss: 0.3491 acc: 84.78 - Test loss: 0.3533 acc: 84.90
# ==========Train Epoch 60==========
# Train loss: 0.3558 acc: 83.97 - Test loss: 0.3495 acc: 85.21
# ==========Train Epoch 65==========
# Train loss: 0.3544 acc: 84.87 - Test loss: 0.3508 acc: 85.31
# ==========Train Epoch 70==========
# Train loss: 0.3570 acc: 85.27 - Test loss: 0.3511 acc: 85.21
# ==========Train Epoch 75==========
# Train loss: 0.3539 acc: 84.96 - Test loss: 0.3495 acc: 85.21
# ==========Train Epoch 80==========
# Train loss: 0.3465 acc: 85.89 - Test loss: 0.3514 acc: 84.90
# ==========Train Epoch 85==========
# Train loss: 0.3504 acc: 84.96 - Test loss: 0.3493 acc: 85.10
# ==========Train Epoch 90==========
# Train loss: 0.3499 acc: 85.62 - Test loss: 0.3494 acc: 85.00

# %% [markdown]
# - dim3
# Train loss: 0.2985 acc: 89.11 - Test loss: 0.2963 acc: 90.52
# Train loss: 0.3551 acc: 86.12 - Test loss: 0.3122 acc: 89.38
# Train loss: 0.2872 acc: 90.09 - Test loss: 0.2694 acc: 91.25
# - dim2
# Train loss: 0.3517 acc: 85.09 - Test loss: 0.3507 acc: 85.42
# Train loss: 0.3537 acc: 85.09 - Test loss: 0.3531 acc: 85.31
# Train loss: 0.3499 acc: 85.62 - Test loss: 0.3494 acc: 85.00

# %%
(0.3507 + 0.3531 + 0.3494) / 3
# Out:
# 0.35106666666666664

# %%
# torch.save(model.state_dict(), 'ckpts/ae20,12,7,5_lr1e-3_l0.0925.pt')

# %%
meter.plot()

# %% [markdown]
# - model5,1 lr1e-2 step50 gamma0.2
# Train loss: 0.5245 acc: 71.96 - Test loss: 0.5274 acc: 72.19
# - model5,3,1 bn+relu step20 gamma0.2
# Train loss: 0.2121 acc: 91.56 - Test loss: 0.1693 acc: 93.02
# Train loss: 0.2021 acc: 92.01 - Test loss: 0.1849 acc: 92.92

# %% [markdown]
# ##
